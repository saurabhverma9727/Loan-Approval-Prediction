# %%
#Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\train.csv") 
test=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\test.csv")

# %%
train_original=train.copy()
test_original=test.copy()

# %%
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
test
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
test.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
train.shape
# Out:
# (614, 13)

# %%
test.shape
# Out:
# (367, 12)

# %%
train['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
train['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
#Univariate Analysis

#Gender
plt.subplot(221) 
train['Gender'].value_counts(normalize=True).plot.bar(figsize=(10,15), title= 'Gender')

#Married
plt.subplot(222) 
train['Married'].value_counts(normalize=True).plot.bar(figsize=(10, 15), title= 'Married')

#Credit History
plt.subplot(223) 
train['Credit_History'].value_counts(normalize=True).plot.bar(figsize=(10, 15), title= '1=Yes, 2=No')

#Self Employed
plt.subplot(224)
train['Self_Employed'].value_counts(normalize=True).plot.bar(figsize = (10, 15), title = 'Self Employed')

# %%
#Dependent
plt.subplot(221)
train['Dependents'].value_counts(normalize=True).plot.bar(figsize = (10, 15), title = 'Dependents')

#Education
plt.subplot(222)
train['Education'].value_counts(normalize = True).plot.bar(figsize = (10, 15), title = 'Education')

#Property Area
plt.subplot(223)
train['Property_Area'].value_counts(normalize = True).plot.bar(figsize = (10, 15), title = 'Property area')

# %%
#Histogram Applicant Income

plt.figure(figsize = (15,10))
sns.distplot(train['ApplicantIncome'], bins = 500, color = 'r');
# Out:
# C:\Users\saura\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Box Plot Applicant Income

train['ApplicantIncome'].plot.box(figsize = (10,5))

# %%
#Box Plot Loan Status

train['LoanAmount'].plot.box(figsize = (10,5))

# %%
#Bivariate Analysis

#Creating crosstable for Y/N
#Gender

Gender = pd.crosstab(train['Gender'], train['Loan_Status'])

# %%
Gender
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
#Dependents

Dependents = pd.crosstab(train['Dependents'], train['Loan_Status'])

# %%
Dependents
# Out:
# Loan_Status    N    Y
# Dependents
# 0            107  238
# 1             36   66
# 2             25   76
# 3+            18   33

# %%
Dependents.div(Dependents.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
#Married

Married = pd.crosstab(train['Married'], train['Loan_Status'])

# %%
Married
# Out:
# Loan_Status    N    Y
# Married
# No            79  134
# Yes          113  285

# %%
Married.div(Married.sum(1).astype(float), axis = 0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
#Education

Education=pd.crosstab(train['Education'], train['Loan_Status'])

# %%
Education
# Out:
# Loan_Status     N    Y
# Education
# Graduate      140  340
# Not Graduate   52   82

# %%
Education.div(Education.sum(1).astype(float), axis = 0).plot(kind="bar", stacked = True, figsize= (4,4))

# %%
#Self Employed

Self_Employed = pd.crosstab(train['Self_Employed'], train['Loan_Status'])

# %%
Self_Employed
# Out:
# Loan_Status      N    Y
# Self_Employed
# No             157  343
# Yes             26   56

# %%
Self_Employed.div(Self_Employed.sum(1).astype(float), axis = 0).plot(kind = "bar", stacked = True, figsize = (4,4))

# %%
#Credit_History
#Property Area

Credit_History=pd.crosstab(train['Credit_History'],train['Loan_Status']) 
Property_Area=pd.crosstab(train['Property_Area'],train['Loan_Status']) 
Credit_History.div(Credit_History.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4)) 
plt.show() 
Property_Area.div(Property_Area.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True) 
plt.show()

# %%
#Dependence of Approval on Copplicants income

bins=[0,1000,3000,42000]
group=['Low','Average','High']
train['Coapplicant_Income_bin']=pd.cut(train['CoapplicantIncome'],bins,labels=group)
Coapplicant_Income_bin=pd.crosstab(train['Coapplicant_Income_bin'],train['Loan_Status'])
Coapplicant_Income_bin.div(Coapplicant_Income_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True) 
plt.xlabel('CoapplicantIncome')
P = plt.ylabel('Percentage')


#Dependence of Approval on Total Income

train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome']
bins=[0,2500,4000,6000,81000] 
group=['Low','Average','High', 'Very high'] 
train['Total_Income_bin']=pd.cut(train['Total_Income'],bins,labels=group)
Total_Income_bin=pd.crosstab(train['Total_Income_bin'],train['Loan_Status']) 
Total_Income_bin.div(Total_Income_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True) 
plt.xlabel('Total_Income') 
P = plt.ylabel('Percentage')


#Dependence of Approval on Loan Amount

bins=[0,100,200,700] 
group=['Low','Average','High'] 
train['LoanAmount_bin']=pd.cut(train['LoanAmount'],bins,labels=group)
LoanAmount_bin=pd.crosstab(train['LoanAmount_bin'],train['Loan_Status']) 
LoanAmount_bin.div(LoanAmount_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True) 
plt.xlabel('LoanAmount') 
P = plt.ylabel('Percentage')

# %%
#Missing value Count

train.isnull().sum()
# Out:
# Loan_ID                     0
# Gender                     13
# Married                     3
# Dependents                 15
# Education                   0
# Self_Employed              32
# ApplicantIncome             0
# CoapplicantIncome           0
# LoanAmount                 22
# Loan_Amount_Term           14
# Credit_History             50
# Property_Area               0
# Loan_Status                 0
# Coapplicant_Income_bin    273
# Total_Income                0
# Total_Income_bin            0
# LoanAmount_bin             22
# dtype: int64

# %%
#Missing value imputation using mode
#Categorical variables filled with mode
#Numerical variables filled with Mean/Median


train['Gender'].fillna(train['Gender'].mode()[0], inplace=True) 
train['Married'].fillna(train['Married'].mode()[0], inplace=True) 
train['Dependents'].fillna(train['Dependents'].mode()[0], inplace=True) 
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace=True) 
train['Credit_History'].fillna(train['Credit_History'].mode()[0], inplace=True)

# %%
#Loan_Amount_Term imputation

train['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
#LoanAmount should be imputed with Median as too many outliers

train['LoanAmount'].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 187.0    12
# 160.0    12
# 128.0    11
# 113.0    11
# 130.0    10
# 96.0      9
# 95.0      9
# 70.0      8
# 115.0     8
# 112.0     8
# 150.0     7
# 135.0     7
# 136.0     7
# 132.0     7
# 125.0     7
# 104.0     7
# 80.0      6
# 81.0      6
# 138.0     6
# 90.0      6
# 158.0     6
# 116.0     6
# 175.0     6
# 144.0     6
# 155.0     6
# 180.0     6
# 152.0     5
#          ..
# 315.0     1
# 101.0     1
# 73.0      1
# 142.0     1
# 48.0      1
# 164.0     1
# 83.0      1
# 191.0     1
# 166.0     1
# 495.0     1
# 59.0      1
# 214.0     1
# 240.0     1
# 72.0      1
# 42.0      1
# 349.0     1
# 280.0     1
# 405.0     1
# 279.0     1
# 304.0     1
# 650.0     1
# 436.0     1
# 78.0      1
# 54.0      1
# 89.0      1
# 570.0     1
# 300.0     1
# 376.0     1
# 117.0     1
# 311.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
train['LoanAmount'].fillna(train['LoanAmount'].median(), inplace=True)

# %%
train.isnull().sum()
# Out:
# Loan_ID                     0
# Gender                      0
# Married                     0
# Dependents                  0
# Education                   0
# Self_Employed               0
# ApplicantIncome             0
# CoapplicantIncome           0
# LoanAmount                  0
# Loan_Amount_Term            0
# Credit_History              0
# Property_Area               0
# Loan_Status                 0
# Coapplicant_Income_bin    273
# Total_Income                0
# Total_Income_bin            0
# LoanAmount_bin             22
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#Missing value imputation using mode
#Categorical variables filled with mode
#Numerical variables filled with Mean/Median


test['Gender'].fillna(test['Gender'].mode()[0], inplace=True) 
test['Married'].fillna(test['Married'].mode()[0], inplace=True) 
test['Dependents'].fillna(test['Dependents'].mode()[0], inplace=True) 
test['Self_Employed'].fillna(test['Self_Employed'].mode()[0], inplace=True) 
test['Credit_History'].fillna(test['Credit_History'].mode()[0], inplace=True)

# %%
test['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    311
# 180.0     22
# 480.0      8
# 300.0      7
# 240.0      4
# 84.0       3
# 6.0        1
# 120.0      1
# 36.0       1
# 350.0      1
# 12.0       1
# 60.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
#LoanAmount should be imputed with Median as too many outliers

test['LoanAmount'].value_counts()
# Out:
# 150.0    12
# 125.0    11
# 110.0    10
# 100.0     9
# 90.0      9
# 120.0     9
# 187.0     9
# 130.0     8
# 108.0     8
# 135.0     7
# 80.0      6
# 104.0     5
# 122.0     5
# 185.0     5
# 176.0     5
# 160.0     5
# 131.0     5
# 200.0     5
# 65.0      4
# 123.0     4
# 180.0     4
# 152.0     4
# 102.0     4
# 70.0      4
# 138.0     4
# 116.0     4
# 143.0     4
# 105.0     4
# 126.0     4
# 140.0     4
#          ..
# 173.0     1
# 157.0     1
# 159.0     1
# 213.0     1
# 61.0      1
# 550.0     1
# 71.0      1
# 225.0     1
# 209.0     1
# 214.0     1
# 103.0     1
# 412.0     1
# 256.0     1
# 234.0     1
# 74.0      1
# 30.0      1
# 72.0      1
# 151.0     1
# 189.0     1
# 142.0     1
# 66.0      1
# 232.0     1
# 390.0     1
# 55.0      1
# 155.0     1
# 186.0     1
# 163.0     1
# 360.0     1
# 77.0      1
# 297.0     1
# Name: LoanAmount, Length: 144, dtype: int64

# %%
test['LoanAmount'].fillna(test['LoanAmount'].median(), inplace=True)

# %%
test.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
# bins included in dataframe
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
test
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate            No
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate            No
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
#bins deleted
del train['Coapplicant_Income_bin']
del train['Total_Income_bin']
del train['LoanAmount_bin']

# %%
#Outlier Treatment
plt.figure(figsize = (15,10))
train['LoanAmount_log'] = np.log(train['LoanAmount']) 
train['LoanAmount_log'].hist(bins=20)

# %%
#Taking Log of smaller values doesnt affect them but doing it on higher values does it
test['LoanAmount_log'] = np.log(test['LoanAmount'])

# %%
#Loan Amount after log
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
#Dropping Loan_IDfromtrain and test data
train=train.drop(['Loan_ID'], axis = 1)
test=test.drop(['Loan_ID'], axis = 1)
train=train.drop(['LoanAmount'], axis = 1)
test=test.drop(['LoanAmount'], axis = 1)

#Adding total Income column in Test
test['Total_Income']=test.ApplicantIncome + test.CoapplicantIncome

# %%
test
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male     Yes          0      Graduate            No             5720
# 1      Male     Yes          1      Graduate            No             3076
# 2      Male     Yes          2      Graduate            No             5000
# 3      Male     Yes          2      Graduate            No             2340
# 4      Male      No          0  Not Graduate            No             3276
# 5      Male     Yes          0  Not Graduate           Yes             2165
# 6    Female      No          1  Not Graduate            No             2226
# 7      Male     Yes          2  Not Graduate            No             3881
# 8      Male     Yes          2      Graduate            No            13633
# 9      Male      No          0  Not Graduate            No             2400
# 10     Male      No          0  Not Graduate            No             3091
# ...

# %%
#Rearranging of columns

test=test[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome',  'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Total_Income', 'LoanAmount_log']]

# %%
x=train.drop('Loan_Status', 1)
y=train.Loan_Status

# %%
x
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# 6      Male     Yes          0  Not Graduate            No             2333
# 7      Male     Yes         3+      Graduate            No             3036
# 8      Male     Yes          2      Graduate            No             4006
# 9      Male     Yes          1      Graduate            No            12841
# 10     Male     Yes          2      Graduate            No             3200
# ...

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
# 5      Y
# 6      Y
# 7      N
# 8      Y
# 9      N
# 10     Y
# 11     Y
# 12     Y
# 13     N
# 14     Y
# 15     Y
# 16     Y
# 17     N
# 18     N
# 19     Y
# 20     N
# 21     Y
# 22     N
# 23     N
# 24     N
# 25     Y
# 26     Y
# 27     Y
# 28     N
# 29     Y
#       ..
# 584    N
# 585    N
# 586    Y
# 587    Y
# 588    Y
# 589    N
# 590    Y
# 591    N
# 592    Y
# 593    Y
# 594    Y
# 595    Y
# 596    N
# 597    N
# 598    Y
# 599    Y
# 600    N
# 601    Y
# 602    Y
# 603    Y
# 604    Y
# 605    N
# 606    Y
# 607    Y
# 608    Y
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
#including dummy variables
x=pd.get_dummies(x)
train=pd.get_dummies(train)
test=pd.get_dummies(test)

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0               5849                0.0             360.0             1.0
# 1               4583             1508.0             360.0             1.0
# 2               3000                0.0             360.0             1.0
# 3               2583             2358.0             360.0             1.0
# 4               6000                0.0             360.0             1.0
# 5               5417             4196.0             360.0             1.0
# 6               2333             1516.0             360.0             1.0
# 7               3036             2504.0             360.0             0.0
# 8               4006             1526.0             360.0             1.0
# 9              12841            10968.0             360.0             1.0
# 10              3200              700.0             360.0             1.0
# 11              2500             1840.0             360.0             1.0
# ...

# %%
train
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0               5849                0.0             360.0             1.0
# 1               4583             1508.0             360.0             1.0
# 2               3000                0.0             360.0             1.0
# 3               2583             2358.0             360.0             1.0
# 4               6000                0.0             360.0             1.0
# 5               5417             4196.0             360.0             1.0
# 6               2333             1516.0             360.0             1.0
# 7               3036             2504.0             360.0             0.0
# 8               4006             1526.0             360.0             1.0
# 9              12841            10968.0             360.0             1.0
# 10              3200              700.0             360.0             1.0
# 11              2500             1840.0             360.0             1.0
# ...

# %%
test
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0               5720                  0             360.0             1.0
# 1               3076               1500             360.0             1.0
# 2               5000               1800             360.0             1.0
# 3               2340               2546             360.0             1.0
# 4               3276                  0             360.0             1.0
# 5               2165               3422             360.0             1.0
# 6               2226                  0             360.0             1.0
# 7               3881                  0             360.0             0.0
# 8              13633                  0             240.0             1.0
# 9               2400               2400             360.0             1.0
# 10              3091                  0             360.0             1.0
# 11              2185               1516             360.0             1.0
# ...

# %%
#Splitting the train data into train and cross validation 

from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(x, y, test_size = 0.70)

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
model = LogisticRegression() 
model.fit(x_train, y_train)
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True, intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1, penalty='l2', random_state=1, solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# Out:
# C:\Users\saura\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=1, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#Cross validation prediction and accuracy

pred_cv = model.predict(x_cv)
accuracy_score(y_cv, pred_cv)
# Out:
# 0.7976744186046512

# %%
pred_cv
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y',
# ...

# %%
#Predition of values for test set

pred_test = model.predict(test)

# %%
pred_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
#Importing submission file
submission=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\submission.csv")

# %%
submission['Loan_Status']=pred_test 
submission['Loan_ID']=test_original['Loan_ID']

# %%
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

# %%
#Creating logistic files
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('logistic.csv')

# %%
####Stratified K-fold####

from sklearn.model_selection import StratifiedKFold

# %%
i=1 
kf = StratifiedKFold(n_splits=10,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(x,y):     
    print('\n{} of kfold {}'.format(i,kf.n_splits))     
    xtr,xvl = x.loc[train_index],x.loc[test_index]     
    ytr,yvl = y[train_index],y[test_index]         
    model = LogisticRegression(random_state=1)     
    model.fit(xtr, ytr)     
    pred_test = model.predict(xvl)     
    score = accuracy_score(yvl,pred_test)     
    print('accuracy_score',score)     
    i+=1 
pred_test = model.predict(test) 
pred=model.predict_proba(xvl)[:,1]
# Out:
# 1 of kfold 10
# accuracy_score 0.7777777777777778
#
# 2 of kfold 10
# accuracy_score 0.8095238095238095
#
# 3 of kfold 10
# accuracy_score 0.8360655737704918
#
# 4 of kfold 10
# accuracy_score 0.8360655737704918
#
# 5 of kfold 10
# accuracy_score 0.7868852459016393
#
# 6 of kfold 10
# accuracy_score 0.8360655737704918
#
# 7 of kfold 10
# accuracy_score 0.8032786885245902
#
# 8 of kfold 10
# accuracy_score 0.7704918032786885
#
# 9 of kfold 10
# accuracy_score 0.819672131147541
#
# 10 of kfold 10
# accuracy_score 0.8360655737704918
# C:\Users\saura\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\saura\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
####Support Vector Machine####

from sklearn.svm import SVC
clf = SVC(gamma='auto')
clf.fit(x, y) 
SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf', max_iter=-1, probability=False, random_state=None, shrinking=True, tol=0.001, verbose=False)
pred_cv=clf.predict(x_cv)
pred_cv
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'Y',
# ...

# %%
#Accuracy Score of SVM
accuracy_score(y_cv, pred_cv)
# Out:
# 0.9813953488372092

# %%
#Predition of values for test set

pred_test = clf.predict(test)
pred_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
#Importing submission file
submission=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\submission.csv")
submission['Loan_Status']=pred_test 
submission['Loan_ID']=test_original['Loan_ID']
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

#Creating SVM files
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('SVM.csv')

# %%
####Decision Tree Classifier####

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
clf.fit(x, y)
DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, random_state=0, splitter='best')
pred_cv=clf.predict(x_cv)
pred_cv
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y',
# ...

# %%
accuracy_score(y_cv, pred_cv)
# Out:
# 1.0

# %%
pred_test = clf.predict(test)
pred_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N',
#        'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N',
#        'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
#Importing submission file
submission=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\submission.csv")
submission['Loan_Status']=pred_test 
submission['Loan_ID']=test_original['Loan_ID']
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

#Creating Decision Tree file
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('DecisionTree.csv')

# %%
####Random Forest Classifier####

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0)
clf.fit(x, y)  
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini', max_depth=2, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None, oob_score=False, random_state=0, verbose=0, warm_start=False)
pred_cv=clf.predict(x_cv)
pred_cv
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y',
# ...

# %%
accuracy_score(y_cv, pred_cv)
# Out:
# 0.9325581395348838

# %%
pred_test = clf.predict(test)
pred_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
#Importing submission file
submission=pd.read_csv("C:\\Users\\saura\\Desktop\\IMP\\1 Loan Defaulter\\submission.csv")
submission['Loan_Status']=pred_test 
submission['Loan_ID']=test_original['Loan_ID']
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

#Creating Random Forst file
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('Random Forest.csv')
